# %%
import requests

# %%
from bs4 import BeautifulSoup

# %%
url='http://quotes.toscrape.com/'

# %%
res=requests.get(url)

# %%
print(res)     # this means we can acess
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(res.text,'html.parser')

# %%
print(soup)
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %% [markdown]
# find give the first occurance and find all give all

# %%
print(soup.find('h1').text)
# Out:
# Quotes to Scrape

# %%
print(soup.find('a',{'class':'tag'}).text)
# Out:
# change

# %%
print(soup.find('div',{'class':'tags'}).text)
# Out:
#             Tags:
#
# change
# deep-thoughts
# thinking
# world

# %%
print(soup.find_all('div',{'class':'tags'})[2].text)
# Out:
#             Tags:
#
# inspirational
# life
# live
# miracle
# miracles

# %%
print(soup.find_all(class_='tags'))
# Out:
# [<div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# <a class="tag" href="/tag/world/page/1/">world</a>
# </div>, <div class="tags">
#             Tags:
#             <meta class="keywords" content="abilities,choices" itemprop="keywords"/>
# <a class="tag" href="/tag/abilities/page/1/">abilities</a>
# <a class="tag" href="/tag/choices/page/1/">choices</a>
# </div>, <div class="tags">
#             Tags:
#             <meta class="keywords" content="inspirational,life,live,miracle,miracles" itemprop="keywords"/>
# <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
# <a class="tag" href="/tag/life/page/1/">life</a>
# <a class="tag" href="/tag/live/page/1/">live</a>
# ...

# %%
lst=[]
lst.append(soup.find_all(class_='tags')[0].text.replace('\n',' ').strip())
print(lst[0])
# Out:
# Tags:              change deep-thoughts thinking world

# %%
tags=soup.find_all(class_='tags')
tags
# Out:
# [<div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
#  <a class="tag" href="/tag/world/page/1/">world</a>
#  </div>, <div class="tags">
#              Tags:
#              <meta class="keywords" content="abilities,choices" itemprop="keywords"/>
#  <a class="tag" href="/tag/abilities/page/1/">abilities</a>
#  <a class="tag" href="/tag/choices/page/1/">choices</a>
#  </div>, <div class="tags">
#              Tags:
#              <meta class="keywords" content="inspirational,life,live,miracle,miracles" itemprop="keywords"/>
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>
#  <a class="tag" href="/tag/life/page/1/">life</a>
#  <a class="tag" href="/tag/live/page/1/">live</a>
# ...

# %%
lst=[]
for tag in tags:
    print(tag.text)
# Out:
#             Tags:
#
# change
# deep-thoughts
# thinking
# world
#
#
#             Tags:
#
# abilities
# choices
#
#
#             Tags:
#
# inspirational
# life
# live
# miracle
# miracles
#
#
#             Tags:
#
# aliteracy
# books
# classic
# humor
#
#
#             Tags:
#
# be-yourself
# inspirational
#
#
#             Tags:
#
# adulthood
# success
# value
#
#
#             Tags:
#
# life
# love
#
#
#             Tags:
#
# edison
# failure
# inspirational
# paraphrased
#
#
#             Tags:
#
# misattributed-eleanor-roosevelt
#
#
#             Tags:
#
# humor
# obvious
# simile

# %%
lst=[]
for tag in tags:
    lst.append(tag.text.replace('\n',' ').strip())
print(lst)
# Out:
# ['Tags:              change deep-thoughts thinking world', 'Tags:              abilities choices', 'Tags:              inspirational life live miracle miracles', 'Tags:              aliteracy books classic humor', 'Tags:              be-yourself inspirational', 'Tags:              adulthood success value', 'Tags:              life love', 'Tags:              edison failure inspirational paraphrased', 'Tags:              misattributed-eleanor-roosevelt', 'Tags:              humor obvious simile']

# %%
lst=[]
for tag in tags:
    lst.append(tag.text.replace('\n',' ').strip())
lst2=[tag.replace('  ','') for tag in lst]
print(lst2)
# Out:
# ['Tags:change deep-thoughts thinking world', 'Tags:abilities choices', 'Tags:inspirational life live miracle miracles', 'Tags:aliteracy books classic humor', 'Tags:be-yourself inspirational', 'Tags:adulthood success value', 'Tags:life love', 'Tags:edison failure inspirational paraphrased', 'Tags:misattributed-eleanor-roosevelt', 'Tags:humor obvious simile']

# %%
for tag in tags:
    print(tag.get_text())
# Out:
#             Tags:
#
# change
# deep-thoughts
# thinking
# world
#
#
#             Tags:
#
# abilities
# choices
#
#
#             Tags:
#
# inspirational
# life
# live
# miracle
# miracles
#
#
#             Tags:
#
# aliteracy
# books
# classic
# humor
#
#
#             Tags:
#
# be-yourself
# inspirational
#
#
#             Tags:
#
# adulthood
# success
# value
#
#
#             Tags:
#
# life
# love
#
#
#             Tags:
#
# edison
# failure
# inspirational
# paraphrased
#
#
#             Tags:
#
# misattributed-eleanor-roosevelt
#
#
#             Tags:
#
# humor
# obvious
# simile

# %%
url='https://boston.craigslist.org/search/sof'

# %%
response=requests.get(url)

# %%
print(response)
# Out:
# <Response [200]>

# %%
data=response.text
print(data)
# Out:
# ﻿<!DOCTYPE html>
# <html class="no-js"><head>
#     <title>boston software/qa/dba/etc  jobs - craigslist</title>
#     <script type="application/ld+json" id="ld_breadcrumb_data" >
#     {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/d/jobs/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}
# </script>
#
#
#     <meta name="description" content="">
#     <meta http-equiv="X-UA-Compatible" content="IE=Edge"/>
#         <link rel="canonical" href="https://boston.craigslist.org/d/software-qa-dba-etc/search/sof">
#     <meta name="viewport" content="width=device-width,initial-scale=1">
# ...

# %%
soup=BeautifulSoup(data,'html.parser')

# %%
print(soup)
# Out:
# ﻿<!DOCTYPE html>
#
# <html class="no-js"><head>
# <title>boston software/qa/dba/etc  jobs - craigslist</title>
# <script id="ld_breadcrumb_data" type="application/ld+json">
#     {"@context":"https://schema.org","itemListElement":[{"item":{"name":"boston.craigslist.org","@id":"https://boston.craigslist.org"},"position":1,"@type":"ListItem"},{"item":{"name":"jobs","@id":"https://boston.craigslist.org/d/jobs/search/jjj"},"position":2,"@type":"ListItem"},{"item":{"name":"software","@id":"https://boston.craigslist.org/d/software-qa-dba-etc/search/sof"},"position":3,"@type":"ListItem"}],"@type":"BreadcrumbList"}
# </script>
# <meta content="" name="description"/>
# <meta content="IE=Edge" http-equiv="X-UA-Compatible">
# <link href="https://boston.craigslist.org/d/software-qa-dba-etc/search/sof" rel="canonical"/>
# <meta content="width=device-width,initial-scale=1" name="viewport"/>
# ...

# %%
tags=soup.find_all('a')
print(tags)
# Out:
# [<a class="appstorebtn" href="https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile">
#         Android
#     </a>, <a class="appstorebtn" href="https://apps.apple.com/us/app/craigslist/id1336642410">
#         iOS
#     </a>, <a class="header-logo" href="/" name="logoLink">CL</a>, <a href="/">boston</a>, <a href="https://post.craigslist.org/c/bos">post</a>, <a href="https://accounts.craigslist.org/login/home">account</a>, <a class="favlink" href="#"><span aria-hidden="true" class="icon icon-star fav"></span><span class="fav-number">0</span><span class="fav-label"> favorites</span></a>, <a class="to-banish-page-link" href="#">
# <span aria-hidden="true" class="icon icon-trash red"></span>
# <span class="banished_count">0</span>
# <span class="discards-label"> hidden</span>
# ...

# %%
for tag in tags:
    print(tag.get('href'))
# Out:
# https://play.google.com/store/apps/details?id=org.craigslist.CraigslistMobile
# https://apps.apple.com/us/app/craigslist/id1336642410
# /
# /
# https://post.craigslist.org/c/bos
# https://accounts.craigslist.org/login/home
# #
# #
# /
# https://accounts.craigslist.org/savesearch/save?URL=https%3A%2F%2Fboston%2Ecraigslist%2Eorg%2Fd%2Fsoftware%2Dqa%2Ddba%2Detc%2Fsearch%2Fsof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof?sort=date&
#
# /d/software-qa-dba-etc/search/sof
# /d/software-qa-dba-etc/search/sof
#
# https://boston.craigslist.org/gbs/sof/d/cambridge-zope-python-mysql-developer/7283136125.html
# https://boston.craigslist.org/gbs/sof/d/cambridge-zope-python-mysql-developer/7283136125.html
# #
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7282574557.html
# https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7282574557.html
# #
# ...

# %%
titles=soup.find_all('a',{'class':'result-title hdrlnk'})
print(titles)
# Out:
# [<a class="result-title hdrlnk" data-id="7283136125" href="https://boston.craigslist.org/gbs/sof/d/cambridge-zope-python-mysql-developer/7283136125.html" id="postid_7283136125">zope / python / mysql developer</a>, <a class="result-title hdrlnk" data-id="7282574557" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/7282574557.html" id="postid_7282574557">✭✭✭Become a Web Developer. No Experience Needed (Remote)</a>, <a class="result-title hdrlnk" data-id="7282195026" href="https://boston.craigslist.org/gbs/sof/d/boston-research-assistant-per-hour/7282195026.html" id="postid_7282195026">Research Assistant | $50 - $55 per hour</a>, <a class="result-title hdrlnk" data-id="7282064687" href="https://boston.craigslist.org/gbs/sof/d/boston-data-science-fellowship/7282064687.html" id="postid_7282064687">Data Science Fellowship</a>, <a class="result-title hdrlnk" data-id="7281579920" href="https://boston.craigslist.org/gbs/sof/d/boston-become-web-developer-no/72815799
# ...

# %%
for title in titles:
    print(title.text)
# Out:
# zope / python / mysql developer
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Research Assistant | $50 - $55 per hour
# Data Science Fellowship
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Senior Rails Engineer
# Senior PHP Developer/DevOps Engineer
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Data Science Fellowship
# Senior Full Stack Engineer
# Senior Frontend Engineer
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Helpdesk Support Technician
# Senior Software Engineer | $120,000 - $180,000 per year
# Research Assistant | $50 - $55 per hour
# Intern for Android or iPhone Task
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# Senior Software QA Engineer / QA Lead (Contract)
# Senior Software Engineer | $120,000 - $180,000 per year
# Linux & Cloud Sysadmin
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# ...

# %%
adresses=soup.find_all('span',{'class':'result-hood'})

# %%
for adress in adresses:
    print(adress.text)
# Out:
#  (Cambridge, between Porter Sq. and Harvard Sq.)
#  (boston: boston/cambridge/brookline)
#  (boston: boston/cambridge/brookline)
#  (Medford)
#  (Remote)
#  (North of Boston)
#  (Boston)
#  (Newton, MA)
#  (Cambridge)
#  (boston: boston/cambridge/brookline)
#  (boston: boston/cambridge/brookline)
#  (boston: boston/cambridge/brookline)
#  (Cambridge MA)
#  (Cambridge)
#  (North Andover)
#  (Cambridge)

# %%
jobs=soup.find_all('li',{'class':'result-row'})
print(jobs)
# Out:
# [<li class="result-row" data-pid="7283136125">
# <a class="result-image gallery empty" href="https://boston.craigslist.org/gbs/sof/d/cambridge-zope-python-mysql-developer/7283136125.html"></a>
# <div class="result-info">
# <span class="icon icon-star" role="button">
# <span class="screen-reader-text">favorite this post</span>
# </span>
# <time class="result-date" datetime="2021-02-26 11:17" title="Fri 26 Feb 11:17:26 AM">Feb 26</time>
# <h3 class="result-heading">
# <a class="result-title hdrlnk" data-id="7283136125" href="https://boston.craigslist.org/gbs/sof/d/cambridge-zope-python-mysql-developer/7283136125.html" id="postid_7283136125">zope / python / mysql developer</a>
# </h3>
# <span class="result-meta">
# <span class="result-hood"> (Cambridge, between Porter Sq. and Harvard Sq.)</span>
# <span class="result-tags">
# </span>
# <span class="banish icon icon-trash" role="button">
# <span class="screen-reader-text">hide this posting</span>
# </span>
# ...

# %%
for job in jobs:
    print(job.text)
# Out:
# favorite this post
#
# Feb 26
#
# zope / python / mysql developer
#
#
#  (Cambridge, between Porter Sq. and Harvard Sq.)
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
#
# favorite this post
#
# Feb 25
#
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
#
#
#
# pic
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Feb 24
#
# Research Assistant | $50 - $55 per hour
#
#
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
# favorite this post
#
# Feb 24
#
# Data Science Fellowship
#
#
#
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
#
# favorite this post
#
# Feb 23
#
# ✭✭✭Become a Web Developer. No Experience Needed (Remote)
#
#
#
# pic
#
#
# hide this posting
#
#
#
# restore
# restore this posting
#
#
#
#
#
#
#
#
#
# favorite this post
#
# Feb 22
#
# Senior Rails Engineer
#
#
#
# pic
#
#
# hide this posting
#
#
#
# restore
# ...

# %%
for job in jobs:
    location_tag=job.find('span',{'class':'result-hood'})
    location=location_tag.text[2:-1] if location_tag else 'N/A'
    print(location_tag)
# Out:
# <span class="result-hood"> (Cambridge, between Porter Sq. and Harvard Sq.)</span>
# None
# None
# None
# None
# None
# None
# None
# None
# None
# <span class="result-hood"> (boston: boston/cambridge/brookline)</span>
# <span class="result-hood"> (boston: boston/cambridge/brookline)</span>
# None
# <span class="result-hood"> (Medford)</span>
# None
# None
# <span class="result-hood"> (Remote)</span>
# None
# <span class="result-hood"> (North of Boston)</span>
# None
# <span class="result-hood"> (Boston)</span>
# None
# None
# <span class="result-hood"> (Newton, MA)</span>
# <span class="result-hood"> (Cambridge)</span>
# None
# None
# <span class="result-hood"> (boston: boston/cambridge/brookline)</span>
# None
# None
# None
# None
# None
# <span class="result-hood"> (boston: boston/cambridge/brookline)</span>
# <span class="result-hood"> (boston: boston/cambridge/brookline)</span>
# <span class="result-hood"> (Cambridge MA)</span>
# None
# None
# None
# ...

# %%
for job in jobs:
    title=job.find('a',{'class':'result-title hdrlnk'}).text
    location_tag=job.find('span',{'class':'result-hood'})
    location=location_tag.text[2:-1] if location_tag else 'N/A'
    date=job.find('time',{'class':'result-date'}).text
    link=job.find('a',{'class':'result-title'}).get('href')
    job_response=requests.get(link)
    job_data=job_response.text
    job_soup=BeautifulSoup(job_data,'html.parser')
    job_description=job_soup.find('section',{'id':'postingbody'}).text
    job_attributes_tag=job_soup.find('p',{'class':'attrgroup'})
    job_attributes=job_attributes_tag.text if job_attributes_tag else 'N/A'
    print('job title:', title,'\nlocation:', location,'\nDate:', date,'\nlink:', link,'\n',job_attributes,'\njob_description,', job_description)
# Out:
# job title: zope / python / mysql developer
# location: Cambridge, between Porter Sq. and Harvard Sq.
# Date: Feb 26
# link: https://boston.craigslist.org/gbs/sof/d/cambridge-zope-python-mysql-developer/7283136125.html
#
# compensation: Comensurate with pertinent experience
#
# employment type: contract
#
# telecommuting ok
#
#
# job_description,
#
# QR Code Link to This Post
#
#
# Seeking someone to help maintain and improve our proprietary contact management system.
#
# Must have strong python and mysql skills and significant familiarity with Zope-2 and Linux.
#
# Must have an established track record handling/protecting confidential information.
#
# Will begin on a contract basis with potential for a permanent part-time or even full-time role.
#
# Must be available to meet in office an a regular basis.
# job title: ✭✭✭Become a Web Developer. No Experience Needed (Remote)
# location: N/A
# Date: Feb 25
# ...

# %%
job_no=0
while True:
    response=requests.get(url)
    data=response.text
    soup=BeautifulSoup(data,'html.parser')
    jobs=soup.find_all('li',{'class':'result-now'})
    
    for job in jobs:
        title=job.find('a',{'class':'result-title hdrlnk'}).text
        location_tag=job.find('span',{'class':'result-hood'})
        location=location_tag.text[2:-1] if location_tag else 'N/A'
        date=job.find('time',{'class':'result-date'}).text
        link=job.find('a',{'class':'result-title'}).get('href')
        job_response=requests.get(link)
        job_data=job_response.text
        job_soup=BeautifulSoup(job_data,'html.parser')
        job_description=job_soup.find('section',{'id':'postingbody'}).text
        job_attributes_tag=job_soup.find('p',{'class':'attrgroup'})
        job_attributes=job_attributes_tag.text if job_attributes_tag else 'N/A'
        job_no+=1
        print('job title:', title,'\nlocation:', location,'\nDate:', date,'\nlink:', link,'\n',job_attributes,'\njob_description,', job_description)
    url_tag=soup.find('a',{'class':'next-page'})
    if url_tag.get('href'):
        url='https://boston.craigslist.org/search/sof'+url_tag.get('href')
        print(url)
    else:
        break
